# %%
import pandas as pd

# %%
df=pd.read_csv("seattle-weather - seattle-weather.csv")
df
# Out:
#             date  precipitation  temp_max  temp_min  wind  weather
# 0     2012-01-01            0.0      12.8       5.0   4.7  drizzle
# 1     2012-01-02           10.9      10.6       2.8   4.5     rain
# 2     2012-01-03            0.8      11.7       7.2   2.3     rain
# 3     2012-01-04           20.3      12.2       5.6   4.7     rain
# 4     2012-01-05            1.3       8.9       2.8   6.1     rain
# ...          ...            ...       ...       ...   ...      ...
# 1456  2015-12-27            8.6       4.4       1.7   2.9     rain
# 1457  2015-12-28            1.5       5.0       1.7   1.3     rain
# 1458  2015-12-29            0.0       7.2       0.6   2.6      fog
# 1459  2015-12-30            0.0       5.6      -1.0   3.4      sun
# 1460  2015-12-31            0.0       5.6      -2.1   3.5      sun
#
# [1461 rows x 6 columns]

# %%
df["temp_max"].max()
# Out:
# 35.6

# %%
df['temp_min'].min()
# Out:
# -7.1

# %%
df['date'][df['weather']=='rain']
# Out:
# 1       2012-01-02
# 2       2012-01-03
# 3       2012-01-04
# 4       2012-01-05
# 5       2012-01-06
#            ...
# 1452    2015-12-23
# 1453    2015-12-24
# 1454    2015-12-25
# 1456    2015-12-27
# 1457    2015-12-28
# Name: date, Length: 641, dtype: object

# %%
df['date'][df['weather']=='sun']
# Out:
# 7       2012-01-08
# 10      2012-01-11
# 11      2012-01-12
# 12      2012-01-13
# 32      2012-02-02
#            ...
# 1427    2015-11-28
# 1443    2015-12-14
# 1455    2015-12-26
# 1459    2015-12-30
# 1460    2015-12-31
# Name: date, Length: 640, dtype: object

# %%
df['wind'].mean()
# Out:
# 3.24113620807666

# %%
df['precipitation'].max()
# Out:
# 55.9

# %%
df[1:30]
# Out:
#           date  precipitation  temp_max  temp_min  wind  weather
# 1   2012-01-02           10.9      10.6       2.8   4.5     rain
# 2   2012-01-03            0.8      11.7       7.2   2.3     rain
# 3   2012-01-04           20.3      12.2       5.6   4.7     rain
# 4   2012-01-05            1.3       8.9       2.8   6.1     rain
# 5   2012-01-06            2.5       4.4       2.2   2.2     rain
# 6   2012-01-07            0.0       7.2       2.8   2.3     rain
# 7   2012-01-08            0.0      10.0       2.8   2.0      sun
# 8   2012-01-09            4.3       9.4       5.0   3.4     rain
# 9   2012-01-10            1.0       6.1       0.6   3.4     rain
# 10  2012-01-11            0.0       6.1      -1.1   5.1      sun
# 11  2012-01-12            0.0       6.1      -1.7   1.9      sun
# 12  2012-01-13            0.0       5.0      -2.8   1.3      sun
# 13  2012-01-14            4.1       4.4       0.6   5.3     snow
# ...

# %%
df.columns
# Out:
# Index(['date', 'precipitation', 'temp_max', 'temp_min', 'wind', 'weather'], dtype='object')

# %%
df.date
# Out:
# 0       2012-01-01
# 1       2012-01-02
# 2       2012-01-03
# 3       2012-01-04
# 4       2012-01-05
#            ...
# 1456    2015-12-27
# 1457    2015-12-28
# 1458    2015-12-29
# 1459    2015-12-30
# 1460    2015-12-31
# Name: date, Length: 1461, dtype: object

# %%
df.wind
# Out:
# 0       4.7
# 1       4.5
# 2       2.3
# 3       4.7
# 4       6.1
#        ...
# 1456    2.9
# 1457    1.3
# 1458    2.6
# 1459    3.4
# 1460    3.5
# Name: wind, Length: 1461, dtype: float64

# %%
df['date']
# Out:
# 0       2012-01-01
# 1       2012-01-02
# 2       2012-01-03
# 3       2012-01-04
# 4       2012-01-05
#            ...
# 1456    2015-12-27
# 1457    2015-12-28
# 1458    2015-12-29
# 1459    2015-12-30
# 1460    2015-12-31
# Name: date, Length: 1461, dtype: object

# %%
df['temp_max'].describe()
# Out:
# count    1461.000000
# mean       16.439083
# std         7.349758
# min        -1.600000
# 25%        10.600000
# 50%        15.600000
# 75%        22.200000
# max        35.600000
# Name: temp_max, dtype: float64

# %%
df[df.temp_max==df.temp_max.max()]
# Out:
#            date  precipitation  temp_max  temp_min  wind weather
# 953  2014-08-11            0.5      35.6      17.8   2.6    rain

# %%
df.date[df.temp_max==df.temp_max.max()]
# Out:
# 953    2014-08-11
# Name: date, dtype: object

# %%
df.wind[df.temp_max==df.temp_max.max()]
# Out:
# 953    2.6
# Name: wind, dtype: float64

# %%
import pandas as pd

# %%
df1=pd.read_excel("Book.xlsx")
df1
# Out:
#     Employee_ID  YearsExperience  Current_Salary   Last_Year_Salary:   \
# 0           501              1.1            39343               30000
# 1           502              1.3            46205               39000
# 2           503              1.5            37731               29000
# 3           504              2.0            43525               33000
# 4           505              2.2            39891               23000
# 5           506              2.9            56642               35000
# 6           507              3.0            60150               37000
# 7           508              3.2            67000               47000
# 8           509              3.2            64445               50000
# 9           510              3.7            64678               50000
# 10          511              3.9            63218               45000
# 11          512              4.0            77345               45000
# ...
